# %% [markdown]
# # Single Neuron Conductance model of HVCX Neurons

# %%
# %matplotlib inline
from brian2 import *
import numpy as np
import pandas as pd
import hvc 
import simulator
import matplotlib.pyplot as plt
import os

# %%
prefs.codegen.target = "numpy"

# %%
figdir = "plots/hvc_ra/"

# %%
prefs.codegen.target = "numpy"

# %% [markdown]
# ### Defining the Conductance Model

# %% [markdown]
# `simulate_hvc` takes the magnitude of the injected stimulus and the values of model parameters (if any)

# %%
G = simulator.simulate_hvc("ra", 150) 
Time = G.t/ms; Voltage = G.V[0]/ms
plt.figure(figsize = (8,5))
plt.plot(Time,Voltage)
plt.xlim([0, 1000])
plt.title("$I_{app} = 150pA$")
plt.xlabel('$t\ (ms)$')
plt.ylabel('$V\ (mV)$')
plt.savefig(os.path.join("plots/hvc_ra/", "fig_sim_1.png"), dpi=300)
plt.show()
# Out:
# WARNING    (string):85: RuntimeWarning: overflow encountered in exp
#  [py.warnings]
# WARNING    (string):85: RuntimeWarning: divide by zero encountered in true_divide
#  [py.warnings]
# WARNING    (string):86: RuntimeWarning: overflow encountered in exp
#  [py.warnings]
# WARNING    (string):92: RuntimeWarning: divide by zero encountered in true_divide
#  [py.warnings]
# WARNING    (string):95: RuntimeWarning: overflow encountered in exp
#  [py.warnings]
# WARNING    (string):96: RuntimeWarning: overflow encountered in exp
#  [py.warnings]
# WARNING    (string):102: RuntimeWarning: divide by zero encountered in true_divide
#  [py.warnings]
# WARNING    (string):105: RuntimeWarning: overflow encountered in exp
#  [py.warnings]
# WARNING    (string):106: RuntimeWarning: overflow encountered in exp
#  [py.warnings]
# WARNING    (string):115: RuntimeWarning: overflow encountered in exp
#  [py.warnings]
# WARNING    (string):116: RuntimeWarning: overflow encountered in exp
# ...

# %%
G = simulator.simulate_hvc("x", 150) 
Time = G.t/ms; Voltage = G.V[0]/ms
plt.figure(figsize = (8,5))
plt.plot(Time,Voltage)
plt.xlim([0, 1000])
plt.title("$I_{app} = 150pA$")
plt.xlabel('$t\ (ms)$')
plt.ylabel('$V\ (mV)$')
plt.savefig(os.path.join("plots/hvc_x/", "fig_sim_2.png"), dpi=300)
plt.show()
# Out:
# WARNING    (string):85: RuntimeWarning: overflow encountered in exp
#  [py.warnings]
# WARNING    (string):85: RuntimeWarning: divide by zero encountered in true_divide
#  [py.warnings]
# WARNING    (string):86: RuntimeWarning: overflow encountered in exp
#  [py.warnings]
# WARNING    (string):92: RuntimeWarning: divide by zero encountered in true_divide
#  [py.warnings]
# WARNING    (string):95: RuntimeWarning: overflow encountered in exp
#  [py.warnings]
# WARNING    (string):96: RuntimeWarning: overflow encountered in exp
#  [py.warnings]
# WARNING    (string):102: RuntimeWarning: divide by zero encountered in true_divide
#  [py.warnings]
# WARNING    (string):105: RuntimeWarning: overflow encountered in exp
#  [py.warnings]
# WARNING    (string):106: RuntimeWarning: overflow encountered in exp
#  [py.warnings]
# WARNING    (string):115: RuntimeWarning: overflow encountered in exp
#  [py.warnings]
# WARNING    (string):116: RuntimeWarning: overflow encountered in exp
# ...

# %%
G = simulator.simulate_hvc("ra", 150, "./configs/xhvc1.json") 
Time = G.t/ms; Voltage = G.V[0]/ms
plt.figure(figsize = (8,5))
plt.plot(Time,Voltage)
plt.xlim([0, 1000])
plt.title("$I_{app} = 150pA$")
plt.xlabel('$t\ (ms)$')
plt.ylabel('$V\ (mV)$')
plt.savefig(os.path.join("plots/hvc_ra/", "ra_150_g_SK_0.png"), dpi=300)
plt.show()
# Out:
# WARNING    (string):85: RuntimeWarning: overflow encountered in exp
#  [py.warnings]
# WARNING    (string):85: RuntimeWarning: divide by zero encountered in true_divide
#  [py.warnings]
# WARNING    (string):86: RuntimeWarning: overflow encountered in exp
#  [py.warnings]
# WARNING    (string):92: RuntimeWarning: divide by zero encountered in true_divide
#  [py.warnings]
# WARNING    (string):95: RuntimeWarning: overflow encountered in exp
#  [py.warnings]
# WARNING    (string):96: RuntimeWarning: overflow encountered in exp
#  [py.warnings]
# WARNING    (string):102: RuntimeWarning: divide by zero encountered in true_divide
#  [py.warnings]
# WARNING    (string):105: RuntimeWarning: overflow encountered in exp
#  [py.warnings]
# WARNING    (string):106: RuntimeWarning: overflow encountered in exp
#  [py.warnings]
# WARNING    (string):115: RuntimeWarning: overflow encountered in exp
#  [py.warnings]
# WARNING    (string):116: RuntimeWarning: overflow encountered in exp
# ...

# %%
G = simulator.simulate_hvc("ra", 200, "./configs/ra_I_A_current.json", duration = 2) 
Time = G.t/ms; Voltage = G.V[0]/ms
plt.figure(figsize = (8,5))
plt.plot(Time,Voltage)
plt.xlim([0, 1000])
plt.title("$I_{app} = 200pA$")
plt.xlabel('$t\ (ms)$')
plt.ylabel('$V\ (mV)$')
plt.savefig(os.path.join("plots/hvc_ra/", "ra_200_g_A_0.png"), dpi=300)
plt.show()
# Out:
# WARNING    (string):85: RuntimeWarning: overflow encountered in exp
#  [py.warnings]
# WARNING    (string):85: RuntimeWarning: divide by zero encountered in true_divide
#  [py.warnings]
# WARNING    (string):86: RuntimeWarning: overflow encountered in exp
#  [py.warnings]
# WARNING    (string):92: RuntimeWarning: divide by zero encountered in true_divide
#  [py.warnings]
# WARNING    (string):95: RuntimeWarning: overflow encountered in exp
#  [py.warnings]
# WARNING    (string):96: RuntimeWarning: overflow encountered in exp
#  [py.warnings]
# WARNING    (string):102: RuntimeWarning: divide by zero encountered in true_divide
#  [py.warnings]
# WARNING    (string):105: RuntimeWarning: overflow encountered in exp
#  [py.warnings]
# WARNING    (string):106: RuntimeWarning: overflow encountered in exp
#  [py.warnings]
# WARNING    (string):115: RuntimeWarning: overflow encountered in exp
#  [py.warnings]
# WARNING    (string):116: RuntimeWarning: overflow encountered in exp
# ...

# %%
G = simulator.simulate_hvc("ra", -150) 
Time = G.t/ms; Voltage = G.V[0]/ms
plt.figure(figsize = (8,5))
plt.plot(Time,Voltage)
plt.xlim([0, 1000])
plt.title("$I_{app} = -150pA$")
plt.xlabel('$t\ (ms)$')
plt.ylabel('$V\ (mV)$')
plt.savefig(os.path.join("plots/hvc_ra/", "ra_-150.png"), dpi=300)
plt.show()
# Out:
# WARNING    (string):85: RuntimeWarning: overflow encountered in exp
#  [py.warnings]
# WARNING    (string):85: RuntimeWarning: divide by zero encountered in true_divide
#  [py.warnings]
# WARNING    (string):86: RuntimeWarning: overflow encountered in exp
#  [py.warnings]
# WARNING    (string):92: RuntimeWarning: divide by zero encountered in true_divide
#  [py.warnings]
# WARNING    (string):95: RuntimeWarning: overflow encountered in exp
#  [py.warnings]
# WARNING    (string):96: RuntimeWarning: overflow encountered in exp
#  [py.warnings]
# WARNING    (string):102: RuntimeWarning: divide by zero encountered in true_divide
#  [py.warnings]
# WARNING    (string):105: RuntimeWarning: overflow encountered in exp
#  [py.warnings]
# WARNING    (string):106: RuntimeWarning: overflow encountered in exp
#  [py.warnings]
# WARNING    (string):115: RuntimeWarning: overflow encountered in exp
#  [py.warnings]
# WARNING    (string):116: RuntimeWarning: overflow encountered in exp
# ...

# %%
G = simulator.simulate_hvc("x", -150) 
Time = G.t/ms; Voltage = G.V[0]/ms
plt.figure(figsize = (8,5))
plt.plot(Time,Voltage)
plt.xlim([0, 1000])
plt.title("$I_{app} = -150pA$")
plt.xlabel('$t\ (ms)$')
plt.ylabel('$V\ (mV)$')
plt.savefig(os.path.join("plots/hvc_x/", "x_-150.png"), dpi=300)
plt.show()
# Out:
# WARNING    (string):85: RuntimeWarning: overflow encountered in exp
#  [py.warnings]
# WARNING    (string):85: RuntimeWarning: divide by zero encountered in true_divide
#  [py.warnings]
# WARNING    (string):86: RuntimeWarning: overflow encountered in exp
#  [py.warnings]
# WARNING    (string):92: RuntimeWarning: divide by zero encountered in true_divide
#  [py.warnings]
# WARNING    (string):95: RuntimeWarning: overflow encountered in exp
#  [py.warnings]
# WARNING    (string):96: RuntimeWarning: overflow encountered in exp
#  [py.warnings]
# WARNING    (string):102: RuntimeWarning: divide by zero encountered in true_divide
#  [py.warnings]
# WARNING    (string):105: RuntimeWarning: overflow encountered in exp
#  [py.warnings]
# WARNING    (string):106: RuntimeWarning: overflow encountered in exp
#  [py.warnings]
# WARNING    (string):115: RuntimeWarning: overflow encountered in exp
#  [py.warnings]
# WARNING    (string):116: RuntimeWarning: overflow encountered in exp
# ...

# %%
G = simulator.simulate_hvc("int", 150) 
Time = G.t/ms; Voltage = G.V[0]/ms
plt.figure(figsize = (8,5))
plt.plot(Time,Voltage)
plt.xlim([0, 1000])
plt.title("$I_{app} = 150pA$")
plt.xlabel('$t\ (ms)$')
plt.ylabel('$V\ (mV)$')
plt.savefig(os.path.join("plots/hvc_int/", "int_150.png"), dpi=300)
plt.show()
# Out:
# WARNING    (string):85: RuntimeWarning: overflow encountered in exp
#  [py.warnings]
# WARNING    (string):85: RuntimeWarning: divide by zero encountered in true_divide
#  [py.warnings]
# WARNING    (string):86: RuntimeWarning: overflow encountered in exp
#  [py.warnings]
# WARNING    (string):92: RuntimeWarning: divide by zero encountered in true_divide
#  [py.warnings]
# WARNING    (string):95: RuntimeWarning: overflow encountered in exp
#  [py.warnings]
# WARNING    (string):96: RuntimeWarning: overflow encountered in exp
#  [py.warnings]
# WARNING    (string):102: RuntimeWarning: divide by zero encountered in true_divide
#  [py.warnings]
# WARNING    (string):105: RuntimeWarning: overflow encountered in exp
#  [py.warnings]
# WARNING    (string):106: RuntimeWarning: overflow encountered in exp
#  [py.warnings]
# WARNING    (string):115: RuntimeWarning: overflow encountered in exp
#  [py.warnings]
# WARNING    (string):116: RuntimeWarning: overflow encountered in exp
# ...

# %%
G = simulator.simulate_hvc("int", -150) 
Time = G.t/ms; Voltage = G.V[0]/ms
plt.figure(figsize = (8,5))
plt.plot(Time,Voltage)
plt.xlim([0, 1000])
plt.title("$I_{app} = -150pA$")
plt.xlabel('$t\ (ms)$')
plt.ylabel('$V\ (mV)$')
plt.savefig(os.path.join("plots/hvc_int/", "int_-150.png"), dpi=300)
plt.show()
# Out:
# WARNING    (string):85: RuntimeWarning: overflow encountered in exp
#  [py.warnings]
# WARNING    (string):85: RuntimeWarning: divide by zero encountered in true_divide
#  [py.warnings]
# WARNING    (string):86: RuntimeWarning: overflow encountered in exp
#  [py.warnings]
# WARNING    (string):92: RuntimeWarning: divide by zero encountered in true_divide
#  [py.warnings]
# WARNING    (string):95: RuntimeWarning: overflow encountered in exp
#  [py.warnings]
# WARNING    (string):96: RuntimeWarning: overflow encountered in exp
#  [py.warnings]
# WARNING    (string):102: RuntimeWarning: divide by zero encountered in true_divide
#  [py.warnings]
# WARNING    (string):105: RuntimeWarning: overflow encountered in exp
#  [py.warnings]
# WARNING    (string):106: RuntimeWarning: overflow encountered in exp
#  [py.warnings]
# WARNING    (string):115: RuntimeWarning: overflow encountered in exp
#  [py.warnings]
# WARNING    (string):116: RuntimeWarning: overflow encountered in exp
# ...

# %%
G = simulator.simulate_hvc("int", 75) 
Time = G.t/ms; Voltage = G.V[0]/ms
plt.figure(figsize = (8,5))
plt.plot(Time,Voltage)
plt.xlim([0, 1000])
plt.title("$I_{app} = 75pA$")
plt.xlabel('$t\ (ms)$')
plt.ylabel('$V\ (mV)$')
plt.savefig(os.path.join("plots/hvc_int/", "int_75.png"), dpi=300)
plt.show()
# Out:
# WARNING    (string):85: RuntimeWarning: overflow encountered in exp
#  [py.warnings]
# WARNING    (string):85: RuntimeWarning: divide by zero encountered in true_divide
#  [py.warnings]
# WARNING    (string):86: RuntimeWarning: overflow encountered in exp
#  [py.warnings]
# WARNING    (string):92: RuntimeWarning: divide by zero encountered in true_divide
#  [py.warnings]
# WARNING    (string):95: RuntimeWarning: overflow encountered in exp
#  [py.warnings]
# WARNING    (string):96: RuntimeWarning: overflow encountered in exp
#  [py.warnings]
# WARNING    (string):102: RuntimeWarning: divide by zero encountered in true_divide
#  [py.warnings]
# WARNING    (string):105: RuntimeWarning: overflow encountered in exp
#  [py.warnings]
# WARNING    (string):106: RuntimeWarning: overflow encountered in exp
#  [py.warnings]
# WARNING    (string):115: RuntimeWarning: overflow encountered in exp
#  [py.warnings]
# WARNING    (string):116: RuntimeWarning: overflow encountered in exp
# ...
